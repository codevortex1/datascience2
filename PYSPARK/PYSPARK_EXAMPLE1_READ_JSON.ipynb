# %%
import pyspark
from pyspark import SparkConf ,SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode
from pyspark.sql.types import StructType,StructField, StringType, IntegerType,BooleanType,DoubleType


conf = pyspark.SparkConf().setAppName('App1').setMaster('local').set("spark.executor.cores", "4").set("spark.cores.max", "4").set('spark.executor.memory', '6g')
sc = pyspark.SparkContext.getOrCreate(conf=conf)
sc.setLogLevel('ERROR')
spark = SparkSession(sc)
# Out:
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/04/21 01:26:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/04/21 01:26:39 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
#Read JSON file
df = spark.read.option("multiline","true").json("/data/informatica/shared/babynames/Baby.json")
df.printSchema()
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# root
#  |-- data: array (nullable = true)
#  |    |-- element: array (containsNull = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- meta: struct (nullable = true)
#  |    |-- view: struct (nullable = true)
#  |    |    |-- approvals: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- reviewedAt: long (nullable = true)
#  |    |    |    |    |-- reviewedAutomatically: boolean (nullable = true)
#  |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |-- submissionDetails: struct (nullable = true)
#  |    |    |    |    |    |-- permissionType: string (nullable = true)
#  |    |    |    |    |-- submissionId: long (nullable = true)
#  |    |    |    |    |-- submissionObject: string (nullable = true)
#  |    |    |    |    |-- submissionOutcome: string (nullable = true)
# ...

# %%
df.show()

# %%
spark.sql("CREATE OR REPLACE TEMPORARY VIEW BABYNAME USING json OPTIONS" + 
      " (path '/data/informatica/shared/babynames/Baby.json')")
##spark.sql("select * from df").show()
df.show()
# Out:
# +--------------------+--------------------+
# |                data|                meta|
# +--------------------+--------------------+
# |[[row-r9pv-p86t.i...|{{[{1527713207, t...|
# +--------------------+--------------------+
